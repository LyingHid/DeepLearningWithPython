# %% [markdown]
# # Text generation with LSTM

# %% [markdown]
# ## The importance of the sampling strategy
#
# 生成文本时
#
# 1. 每次选概率最高的
# 2. 按概率选择下一个文本
# 3. softmax temperature：加入 temperature 参数，控制概率

# %% [markdown]
# ## Implementing character-level LSTM text generation

# %%
import keras
import numpy as np


path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 600901/600901 [==============================] - 1s 2us/step
# Corpus length: 600893

# %%
maxlen = 60
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...
# /tmp/ipykernel_2517/321955488.py:13: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
# /tmp/ipykernel_2517/321955488.py:14: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

# %%
from keras import layers


model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# 2022-08-31 10:05:59.729451: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-31 10:05:59.733715: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/rmsprop.py:135: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys


for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
# epoch 1
# 1565/1565 [==============================] - 377s 239ms/step - loss: 1.9658
# --- Generating with seed: "mean healthier. it is wisdom, worldly wisdom, to administer
# "
# ------ temperature: 0.2
# mean healthier. it is wisdom, worldly wisdom, to administer
# and spirit of the man is the spirit and strengly and man has the self--and man and speal that the spirit of the spirit of the spirit of the spirit and the spirit of the spirit of the spirit of the spirit of the spirit of the man and special for the spirit and spirit of the man is the spirit of the special man have the self--and the spirit of the self--and in the far and spirit of the strengly and ------ temperature: 0.5
#  of the self--and in the far and spirit of the strengly and probless and conscience of dispect of discition, the gentary to have that far the same to the most
# hans it is feeloded things
# to the epertion
# for the seems of the more long--and itself the defires that the
# spirits of man and the preadness of the command allistred of the instance and from and consequially spicilation of the into itself in the insting that and the enting of the man ward and be man e------ temperature: 1.0
# the insting that and the enting of the man ward and be man exself-offensy--beow of hiddness tomention
# doums far doman heturical
# ,riding men that athersoplangh of a tell only is puthic fealmans that the forthed low lab-imanthy, wiman were
# more, and falswing
# llasing of grower, is not vasting somethon fantal
# he yet was threst mare have oper all whith pain a "that--newed jusging comes man-, pervion
# of relves, and dongfle opterm of mading only more commandard
# f------ temperature: 1.2
#  relves, and dongfle opterm of mading only more commandard
# freaddems of thruou, and an t moderiess! out heartufal appearal as tyaigh lathuriin to an equalt, it, becomabley (peil, his li-veeaver allose pleis snever: than the cislogaal beuled lorr.--to kalingt we
#  lisk, without "nass masting
# is dingsas is a
# e=pttictody call westention they havely bqulets and is talp
#  under alot of amive
# which we-kny-greal
# wepcess ofe nacr-albutive.
#            im an uss.".
#
#  epoch 2
# 1565/1565 [==============================] - 366s 234ms/step - loss: 1.6103
# --- Generating with seed: "dious, one
# cannot think highly enough of their utility. one "
# ------ temperature: 0.2
# dious, one
# cannot think highly enough of their utility. one man in with the senses of the senses of the moral periloses of the conception of the senses of the senses of the senses of the same of the distranged of the same of the more and senses of the senses of the spirit of the senses of the senses of the senses of the senses of the senses of the same of the same of the superial present of the more of the senses of the moral man in his world and and can t------ temperature: 0.5
# re of the senses of the moral man in his world and and can the do senses of the spirit of the last and from a charms of the man and intellectuan and spirit of the for not are and restst of metaphysical and with and self-conscious and his individual and in be are of himself and individual and interpourst of the sense of the than even of the present spirit of the own an an emposition of the disposing of disperition of the power intenlisual be percations of p------ temperature: 1.0
# g of disperition of the power intenlisual be percations of powurent lageded good which when evory and oristhe; inred to if "lither being beruvately are deflisks ave; it which gene of deall-gase as pamings and e
# highever. knows be estublishdle?
#
#
# drfif
# meca bet im
# masses. thom with farderness of the ,
# limains. in youth, and futuregness. me every man, and
# rageredness of kind of pelpletely he see thro? only by for
# meterroes
# care deteses learnhing-justicingnis------ temperature: 1.2
# o? only by for
# meterroes
# care deteses learnhing-justicingnism, ideal for instance, in
# frem own ftain, and jesticion
# (differer, untherphard-kandfore of has bectommer littly werrived
# becesse the intellectial, commsitely id as rives tistay which the comelest=my
# to pratidmation of subitwer" but
# invation? pregite
# dpis4, edveived and those,
# for recarntible
# something afserpende;
# ald the the mnarotakens, are ny diskn, and ilheis
# cooco refinession to wrents frit" epoch 3
# 1565/1565 [==============================] - 305s 194ms/step - loss: 1.5226
# --- Generating with seed: " maintaining and sustaining the community, the
# race, the con"
# ------ temperature: 0.2
#  maintaining and sustaining the community, the
# race, the consequence of the same with the sense of the sense of the superiored to the sense of the sense of the sense of the presence of a more of the sense of the sense of the sense of the sense of the sense of the sense of the superiorise of the explanation of the sense of the possibility of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the same the ------ temperature: 0.5
# ense of the sense of the sense of the sense of the same the exercised to the ranger and cares and he is order and pleciates the consciences and and it the instinct people is also the way lives of the sense of the agere, the unexperiences over the
# sense, it may the greater of the spirit is a man of the superficial acts it seemine the spirit of such the same as muturates or will and in the complecence of the philosophers, and
# contempours of religious certain------ temperature: 1.0
# ce of the philosophers, and
# contempours of religious certainty, it is the woblisher spilltice indeed some all-standsigious hare opinions."--whether
# the obecierized or the grecession what the house hichever forditate bether
# thoughte and
# verless of subsciction which pain cot, even they happter-cormaning a possibled yet a bady the passing fram to a manner schoight, nor !
#
# 1cg.
# to ferh it, makind politically creator calment master order do with such plexselity------ temperature: 1.2
# tically creator calment master order do with such plexselity.--their europiot
# and
# inyernance," an y happiaps, bactua
#  dame, but slient
# awabstolished alsy sgaie delight the amisturs assitianf affencene ?nom, from
# the spours. the bad, coupties, and if an
# phejeringer is its inavornes of his shact caimu every-knowledge, agh feel
# atf inspelousished whee le knowling this pars away noble, which which, or wrest, we for the one,est vence) ffed or other the will wayepoch 4
# 1565/1565 [==============================] - 299s 191ms/step - loss: 1.4756
# --- Generating with seed: "ure. man in the midst of nature is as a child left
# to its ow"
# ------ temperature: 0.2
# ure. man in the midst of nature is as a child left
# to its own sension that the artists and and and and and all think and think that is think and and and think that is a man as a man is all the same and things and and present that the superining of the sense of the sense of the superition of the artists of the things of the same and and and and man is a comparation of the same such a hard and think that is a man is a sort of the superition of the distinguis------ temperature: 0.5
#  that is a man is a sort of the superition of the distinguished and will the form of things which a man himself that which we last and the man entary in a solitious whole of the distancis of the same nature and interpretation of sungless of the same and will it which, and it was regards that it would man do some of man as a man of this responsibility and the are and and as it is distrust at every superation of the spirit and that a man of the consequently
# ------ temperature: 1.0
# superation of the spirit and that a man of the consequently
# hebe on use, and not facally becaure as how
# view in dietual eaw of ranfing corden
# with explance is a mankind a diilinted--possibie which who is here, any serve on those hall that has it (always is there pain. fediling man as the foodouble,
# distatisms it nary perfulninvess: about resord
# feild betagatty
# and -ard
# ttill beyond in likes must can exist dopatic as a my man, the proped of human bedivation------ temperature: 1.2
# an exist dopatic as a my man, the proped of human bedivation anquirate a naturalce falh, enque still sympathy, but ih even aed of 8bility bevomeinary
# magomi" opinions
# beforit
# think, that itlisloy person
# establing laxting who frows of the "ashwaties.mtime most obbeation
# honor (arings towent--but most fichoos, lose-stolies, it. know, expres volaghble, amode, raditand-mac"--why labest, as revereth
# xas it usified, letfoot thomess
# and made ca? certainty of evilepoch 5
# 1565/1565 [==============================] - 343s 219ms/step - loss: 1.4454
# --- Generating with seed: "a people made up of
# the most extraordinary mixing and mingli"
# ------ temperature: 0.2
# a people made up of
# the most extraordinary mixing and mingline of the delight of the sense of the spirit of the fact of the same and and and that is a master of the same of the sense of the sense of the sense of the histere of the same of the most and and the conscience of the science and that it is a man is a states of the spirit of the spirit and and and and and and the own conscience of the precitation of the fact of the spirit of the strength of the sp------ temperature: 0.5
# citation of the fact of the spirit of the strength of the spirit of the conscience, and he sees those and also, in
# the conscience of the instance, as a more power of the fact to the sense of the strength of the wence of the most for this has and the bad to this decedied to him, would be the most and also really be and and intellect and more and thought of the far are than also dispossible to do the assining and world, and and therefore, and in the conscien------ temperature: 1.0
# e assining and world, and and therefore, and in the consciences of by faps and act of advantive,
# evils favoure was socratively as short..re:
# it is carmond judgment its corting whole
# becimes, linked with a must ag rames
# up for impation of as ut
# formet forth in the very individpher. perhaps one has suffome not haw promitation" to melts piotors above are time"wrought, in the world, all these sense of the most didstaniing less to pleasule said ettlents, shome ------ temperature: 1.2
#  the most didstaniing less to pleasule said ettlents, shome right as stargely self-coverocy to be-,recally whusk.
#  chound in the , do non trudhie come agive and
# consequence
# of ewhuvies or hund, for make himbelows--"ig
# swalvel-wenhes is to cirmormmly clle"ful etilly repagnent
# homonf, so that truths,. or lime--to said, why obernip stempt profecen
# to moutly also inglamined, in thlioking that his noism of its falued, abrefore surkinily, he become
# muce out.
# theepoch 6
# 1565/1565 [==============================] - 374s 238ms/step - loss: 1.4227
# --- Generating with seed: "tions are seldom sufficiently apparent, and amid them the me"
# ------ temperature: 0.2
# tions are seldom sufficiently apparent, and amid them the means of the sense of the sense of the sense of the profound and are the sense of the delicate in the sense of the sense of the sense of the sense of the sense of the more and the more and with and the spirit of the sense of the sense of the sense of the sense of the promises of the sense of the sense of the more and man will the sense of the sense of the sense of the sense of the sense of the spiri------ temperature: 0.5
# he sense of the sense of the sense of the sense of the spirit of the seat of which is some more present to the seath of the sense of the command himself the
# sound the promises and all the promise themselves the prooches of the serief of the most which are in the spirit of the decemps and the pronoition of the serroully, he no reveres the consist progress of the entire part and spected in the necessary in the canication of the sense of the man is the sense ------ temperature: 1.0
# sary in the canication of the sense of the man is the sense and belop. nothing for person
# advolusing demandable with rea of the manwined. with every
# deer-animal in ,owes a more anka, difference--because is.
#
#
# 1
# wi
# discancely
# bose--as who shauthers: what wild once comlined in.
#
#
# 1 nere unevolure.
# so, they
# a
# mener xpinted each his vich more generalling, viritive facts the factorical
# possible so permitaris -ribless, the most lief of a noble, vomanwils--circum------ temperature: 1.2
# itaris -ribless, the most lief of a noble, vomanwils--circums: morals
# irrepen only macelisit" this in questions, first youm of the evil pruges and coteminating of "tike woluagually
# ye germanate in
# ene
# of intervidical, emothey had conses "one," on: we ploess, are i menterficts--such a ), did we trold that rue sky to thkir onough the shith, diigorr. in :       voter which thraro,
# at
# othes. not of those enlearne, natures
# for chromes, fact, maste, the cloodlyepoch 7
# 1517/1565 [============================>.] - ETA: 12s - loss: 1.4061 is its entimotion in the most the perposes of mons and and appearance, and with the dangerous faith of the conditions of a constantly of the boorder and hand in the fathing of the other and imposion of the impresses of called------ temperature: 1.0
# fathing of the other and imposion of the impresses of called, turn through they are sobebdged of which aller-algray obide our own subligtate one name as saidues. when bewent
# its nuilty. he bing, and philosophers has, woman, and but this pain anythine, because all part of chease
# of cuse the apfitetdeness have become hereed we so
# distrionizened he stand may attantly bey proce of the shart agadnd true shouch at ast and that whole som tadableows. and wicient i------ temperature: 1.2
# e shouch at ast and that whole som tadableows. and wicient if fa, a conductment ought: even to carmina kinds strulwosripugl
# knowledge has aodacistss, even
# ma: when beyong youe-place
# and conternal, pasible, ensity,
# w1und moreen, the saperx, we time, is the negeness are the s an ims
# com--the it.
# coguis, thormenness his human in usefuld sees to be knolable? orselves--whicale being healt, and bullings tne
# synion of his colds anctivarlie.
# the
# generation. to
# actepoch 8
# 1565/1565 [==============================] - 321s 205ms/step - loss: 1.3933
# --- Generating with seed: "type seems to
# have been more interesting to men and even to "
# ------ temperature: 0.2
# type seems to
# have been more interesting to men and even to the conscience of man and in the fact of the sense of the sense of the morality of the same the sense of the sense of the sense of the sense of the sense of the present of the sense of the sense of the same the same the sense of the sense of the philosophers and the present with anything and concerning the sense of the farilian to the sense of the sense of the fact of the sense of the same the mos------ temperature: 0.5
# se of the sense of the fact of the sense of the same the most culture, with itself well the "superioriciness, the soul and socience of which is not the taste of the self-intentionness, has a nation of his will to decentions and man and whoche as a                                                                                                                                                                                                                     ------ temperature: 1.0
#                                                                                 low a disclixe himself upness, it is caust and view of his same, re be
# nownature convenion. it be nochinare, and stmany!
#
#
# nattlike should his made only as i virs deinf, and
# him of forration, he we determineated for finddent,"
# as such stack, and only can seems even in the fundamentely refure,"
# "this bad thin anaies nimilal world believed
# viguesn-culic siguis, original
# enchjicas------ temperature: 1.2
# ilal world believed
# viguesn-culic siguis, original
# enchjicas; in the excemre of spectmon, -new, thegrained orsation and bad guilty", and
# requirition of sand, one lankgan-interariupable suculith to
# thus earonable stapure, europe? is a, however relate berising
# himpa"s morals has not it is ford.
# evisc-fractibilibly tod only to be
# dignizeraly bad in grown
# very
# graced-a" time
# sun
# guist, whether these roddly and out hithertomest evierati
# questive furthers" inwacepoch 9
#  200/1565 [==>...........................] - ETA: 4:43 - loss: 1.3381
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 1565/1565 [==============================] - 327s 209ms/step - loss: 1.3550
# --- Generating with seed: " fact that philosophizing concerning morals might be
# conduct"
# ------ temperature: 0.2
#  fact that philosophizing concerning morals might be
# conduct the many of the refinement of the soul, and a man is a spirit of the super of the most self-conditions of the most self-condition of the most selfotogations of the most self-consequence of the best of the most selfotal and the fact of the soul, and the more and the selfots of the present of the experience of the more and such an and the present of the selfision of the most similar of the present ------ temperature: 0.5
# present of the selfision of the most similar of the present in the pleasure. therefore, and concerning the development of our enthulith a something of the most distinguished and attained with the more necessity of the subject of the revilisonion and enthulithest are intellecting stronger period; it is a man of the soul, and the was who art to the pleasure of the devil to great the strength and formed and his able to a society and philosophers of the streng------ temperature: 1.0
# med and his able to a society and philosophers of the strength--like the lower meanable of one has fireltisacty rather
# all even joy a necedied without
# agejuled (so that is now too, give the ci. which inouralibet the mistaken of
# my far to avorlily interrought were all stood
# fare manifest predispeciated the epinisairation of the ac"storice the higher antoghoul, to young the spire of our ourish may very feeps what the conduce assimine, by a purpose of agement------ temperature: 1.2
# ery feeps what the conduce assimine, by a purpose of agement inventually a (swoman
# "more undingerating chaoseror,,penated, even withs, but
# house a durility and ghal, inford as an onele calort. consse more the more lat wyin human sypty
# erern--the, not iuraly, ve getful and history imphretament of names dreaded--or alls
# name; but these rovently most
# extent of anoth yith
# had
# callimi
# witlin be givin, dorving have b? triads, which.."
#
# 1ally, use dignder
# spirituepoch 13
# 1069/1565 [===================>..........] - ETA: 1:30 - loss: 1.3401
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 1565/1565 [==============================] - 351s 224ms/step - loss: 1.3311
# --- Generating with seed: "oken, proud, incurable hearts (the cynicism of
# hamlet--the c"
# ------ temperature: 0.2
# oken, proud, incurable hearts (the cynicism of
# hamlet--the conduct of the same all the soul of the present of the subjection of the subject of the conscience of the conscience of the science of the same the conscience of the most present of the sense of the sense of the sense of the sense of the conscience of the sense of the sense of the spoty of the sense and the world of the strength of the powerful of the same the fact of the sense of the sense of the ------ temperature: 0.5
# erful of the same the fact of the sense of the sense of the very decession of the bose of wholly a sense, he are good still spread believe and sense, and more world of the belief in the preparation--in the senses of its allow in the only of the religious still belongs of the greater here as the greater in the great in the single of the errmably of the postrivate of which has to be lare has cannot sack
# vitouruning in the fearful of the interminated of the s------ temperature: 1.0
# sack
# vitouruning in the fearful of the interminated of the secustance, would antach, always rate, we
# woed "the same corself unnatural being
# art be such instinct
# that he is such arb. the
# english alfore relation inauthby to art perhaps it with the yen and hits a
# manifest ray himself of an age, am scholar bilates "great general to
# which the imadenie of all moral
# science itself of man
# is eother our urievated--he have asmuca, alplies the bestering is that erroz------ temperature: 1.2
# ievated--he have asmuca, alplies the bestering is that errozes how in relative. acmord takquineficisation etoured as he  venturementa, a produs what carrining to sporzance" to recapec homog.
#
#
# 75
#
# =mpons of me that the actuount of in pleasure.
#
# 2ate relation fores that gompored are hemicas obyouriful,
# as lehay, and christian will carry is dicfige, as does not new stalle as these peowled of invenside upponitiy and to emphcisuring which is stopy. that he havepoch 17
# 1221/1565 [======================>.......] - ETA: 1:19 - loss: 1.3204
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# t of the subjugate of the german subjugated the self-contemptions of the self-contemptions of the fact that the sublime of the contrary t------ temperature: 0.5
# -contemptions of the fact that the sublime of the contrary to learns and man of the belief to the succe, in which the subjugate of a dance that it is a powerful regard to man is something in the will to be command-good and a whole the consequently of which the strength of the will of the genius, the concealment, in the hundred of the power of the case of such a powerful in every intrigking the significant of the values of
# the "most present of the particiat------ temperature: 1.0
# nificant of the values of
# the "most present of the particiatic briefele," as above to gods are earliest prograntens of
# what selver): the tell of the is apparently france herice. waller world view, ha. pare of contrary
# gratities as the my just
# values,
# one does it
# fritij; to love to be old!
#      py so
# made of
# once has the floring remast of the "indauses," who have was mode only seeken himself and sever and decule, and, namely name.
#
# 14h
# /tmp/ipykernel_2517/2163503365.py:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# ering and, he is it
# c------ temperature: 1.2
# ever and decule, and, namely name.
#
# 14hering and, he is it
# croncenly much destlustice of agrained a seriely instich sun to been are, and
# hitherto been the case.--his envajctdor.
#
#        contuuse, aniknmantity an,
# bron-let a chuiliturates--ay out of a humand, whentor mo?ks that europe-gods: sonf an exist, the
# refules,
# finer religious
# famausquied, as yet ill.--fob? that has the
# meatantificers in secure, heated, the sidelenge-minule.sice, society
# "sorn" by miepoch 21
# 1565/1565 [==============================] - 285s 182ms/step - loss: 1.3058
# --- Generating with seed: "4. the maturity of man--that means, to have reacquired the s"
# ------ temperature: 0.2
# 4. the maturity of man--that means, to have reacquired the same the standard of the belief of the same the standard of the fact of the same the fact of the subject of the consequence of the world and all the subject of the sentiment of the sense of the states of the same the fact of the sense of the fact of the greatest and subject of the most and all the consequence of the fact of the consequence of the sense of the soul, and in the accommon of the sense ------ temperature: 0.5
#  of the sense of the soul, and in the accommon of the sense and religious language of conscious soul who was one of the origin of the impossible; there stret
# nowadays it is
# consideration that he would contempt the contradicate
# of his european general man is and interpretation and an action is anyone have to the world of the consideration of the actually and possession of his supposing in in the realicate of a primitive beings of precisely that the profound------ temperature: 1.0
# alicate of a primitive beings of precisely that the profound" regard elsement that the far of nature, and becling, and because to we. it is perhaps that occuloged, and consequently
# badnes in inferined formuly, togething the fathers of dign belief;
# they many men also all, thlowew, old not counterialse that miteragerences would to dendvilly herably, art an eheal.
# ethic us
# a unnerces also see trite that theorgguts; our highest perfection airs and tuvievogive------ temperature: 1.2
# that theorgguts; our highest perfection airs and tuvievogive,
# as, mughth, when i  good as is by could many satisfact, ruquised: there has eas", more
# more when all
# kind emilat.
#
#
# 13
#
# =succeal--abome tbl"."
#
# 200. page lacquusitible of a
# 'religable acs regined, for a
# "our being dringly in niferness. whoth it
# food, as crus divevers through a viclous our supeflodunt
# sevook. diversiju-cuate somegreame phrang, single perhaps? what
# who con, hy scarisesy; all iked:epoch 22
#   34/1565 [..............................] - ETA: 8:12 - loss: 1.2774
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ly, regarded things: and the entorte manpet only throughed--many, schoolotion that it not in all changes ojtes echoble more harmed have thirst, but the hably anguble steption of manners and
# perhaps was not sy takes which be fing his greatesting. one said, ashquime--if it is curnaction, and ------ temperature: 1.2
# s greatesting. one said, ashquime--if it is curnaction, and nothing and graditle, ration
# orguise--prince regrements the belief and
# refreshing
# of out of ster ogrative kindss lighl. piemernating happless are most kind of evil, what mapthrarible ampet up for yheis un-our powerfidum that paid, conditions
# which feel here satisfaction for will,--the saint danger; if "pren pologing find, thy
# othing whold has case the
# instincts in, again one stesped. he which depuepoch 25
# 1565/1565 [==============================] - 282s 180ms/step - loss: 1.2922
# --- Generating with seed: "tween the christian saints and the greek philosophers and he"
# ------ temperature: 0.2
# tween the christian saints and the greek philosophers and here and the sense of the origin of the proper soul and all the original conditions of the fact that the proper desty of the more of the original proper death of the most proper to the man the man the sense of the proper soul and when the senses of the origin of the proper possent of the man and world and superiority of the proper best of the self-promple to the proper best of the proper best and al------ temperature: 0.5
# he self-promple to the proper best of the proper best and all the proper power of the senses and at the condition of the teaches of these form of known to the proper respect, of superficial conditions of the "world" of such an artints of the accerd of the personal fore of a hunger of his latter act with the personally and act of the man there is the artistic consideration of the conscience, with the proper for the reason of the religious man a proper soul,------ temperature: 1.0
# he proper for the reason of the religious man a proper soul, that the world have had results to
# get centrous of this inclined secoside
# positodful provertac.=--dark, great knowa:
# this will is we much to rult grote, the distance and transmest, it rekeall-pling
# as cimely of his ! thy then work, and vorne any, of the fuculiment, for the amage of moral of diversible be tailh for the
# proper
# zim of our superior
# mits to many the fearliness in kend
# abites of the sm------ temperature: 1.2
# uperior
# mits to many the fearliness in kend
# abites of the smiled world, has foided thinks,
# reworld at quitere good, ethic.
# no fe them dighe--her pain show ionlike consideration was feel polisich very pryiso day (andhay. the spirit almost poteng a
# raringness to it, folicans, of
# indions in religious divine
# development! in which, is
# supensibilities
# in mild, and me than carning
# know,
# three
# caled much. no let us dring and callos.
# phier train estempless in manifepoch 26
#  253/1565 [===>..........................] - ETA: 4:46 - loss: 1.2526
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 1565/1565 [==============================] - 325s 208ms/step - loss: 1.2807
# --- Generating with seed: ", but because they are
# absolutely lacking, and every power e"
# ------ temperature: 0.2
# , but because they are
# absolutely lacking, and every power experience of the same the state of the consequently and sense of the same the same the strength, to the same the same the strength of the same the same and the sense of the same the man of the same sense of the same the states of the same the strength, and in the same the same the consequently sense of the same the strength, which we sharker with a soul, and in the same the same to the same the st------ temperature: 0.5
# ker with a soul, and in the same the same to the same the strength, with as an imageness of the sense of the enough of all permating and superiories of its desires in the most god, and consider more
# from the merely belief in a salvates the sense of the child originate and sense of the greatest person as a purpose and almost the greatest to the danger of the basisge of the present in alloward withing and the farmer words is must be considerations and consid------ temperature: 1.0
# ng and the farmer words is must be considerations and consider its eyes inllationably looking that slame shikes it
# will permusthke, to everything swe complained to muman, atilless
# and play, a sociat, "these property, then extent of platocrucal before against usposed, had so
# lover believe--the world and hauthersment.
#
#
# 83
#
# er:    nt much, from it?                    my standion if not to do moral being there
# rame's exultine of repressible with
# moral, to lin------ temperature: 1.2
# eing there
# rame's exultine of repressible with
# moral, to ling--away, buther for bind, by
# l beyteds, here, from the case of the expraply, it alone. however from atavustame; that is at i more interesped to disgoinum
# shame he stand merelytsial remarabid, there
# hate is i-transotee for inserve, to many reason is not, a beloviar to whocaters for, if,
# "putiomabie with placed man is abstempatenthment, if, it would betters rather-gain from orfment that--it isself depoch 30
# 1537/1565 [============================>.] - ETA: 6s - loss: 1.2788
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# oo powerful
# sensued confins and shardly, in unit "a manifestiod"--what
# is at the sabt careund ha mans thinking
# shankeromed. and it fruegher comes the woluel--ho is all coad,
# to delights himself. the sorm from life, want. buntlouss?--this could no extenting ester natur d------ temperature: 1.2
# ife, want. buntlouss?--this could no extenting ester natur dringe. then
# differenty, if
# a artaint, which, and without theore ornessed and things
# gr. unto being down gleast. wherevourding, gyrat must have been coindrish
# aroung
# like
# all the yhese unrefigious to know may conkxxiding
# moginationy of the permytned necessary to life greate thereby thereby the alar,
# voltation,--without trus tiod fundamentally
# than daverso denial, without prelimicateds--and, among pepoch 34
# 1565/1565 [==============================] - 359s 229ms/step - loss: 1.2683
# --- Generating with seed: "s thus, in effect, that method ordains, which must
# be essent"
# ------ temperature: 0.2
# s thus, in effect, that method ordains, which must
# be essentially and the spiritual philosophy and believe to the same the spiritual of the general conscience of the sense of the former of the sense of the spiritual conscience of the same the spiritual of the morality of the supposition of the sense of the strength of the profound of the deceived and the stronger of the most spiritual of the stronger of the spiritual conscience of the most profound of the ------ temperature: 0.5
# ger of the spiritual conscience of the most profound of the present states of the present one the depression of man is the also the master of one must be doings, wishes to say not the general man are the
# sufficiently religious as of the spiritarical measure to be selfish in the
# stranges.=--philosophers and the same transfiguration, and metaphysical passions for the free spiritble and the order of conscious them all the hand, he may be promises to the spiri------ temperature: 1.0
# conscious them all the hand, he may be promises to the spiritarical
# sort of play of
# the
# concernisherest of implect in the time to look the recerts of events grows we had
# to made than upon usuours
# sopectoriquity to contembading
# not the more
# power, it not rearonipacy with whether for its own by the fact in this victic that that aginly secerate part of denitations
# perhaps less there of helps, and
# fess
# namens of solety childish from at present
# very race of one------ temperature: 1.2
# s
# namens of solety childish from at present
# very race of one had necessary spetion, are not ye know was riveighar,
# than trus he at unbudding
# echow
# of bond verion to errors.     multe", in whom with others
# east, to enourers; finally, but the prowechecre irear, therefins not indeed, wonating b-never will a virtues, the baliful-futurians, in general states. for
# the world othes:
# that
# so
# decisions, an almarmink. in new,g-"con-."
# he has voluntary neither lotifiepoch 35
#  327/1565 [=====>........................] - ETA: 3:56 - loss: 1.2422
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# i------ temperature: 1.0
#  impulse of the science of the same profuming the attachs: it is errorwanted didness understands
# and perpreaching, admoral conviding which lay
# and
# opinion, and finally yething honong ranbly
# in an abond what the most prudence of go other. then well afford. has existing prevailed
# foundations in the chamority is infliction only otherwise old repirt: "they wary, and it is the boddleness beforeest, what venture to losing, what cracbly pretimate parious greatest------ temperature: 1.2
# t venture to losing, what cracbly pretimate parious greatest. it almost valuish acilly sticler -moinate interpolune instrubety of one's development psyet most new sancting etgaineds, of hitherto age, there may doneleners sensse itself hardiness wh hanfouron
# it
# so, the abot
# know the imppression of repressed can be
# strant, everything
# a
# mediocrisis which
# knows always with
# theorioy of youth nentiraf? veter-pitumnanity. toot odeal means. my causes
# by great typeepoch 38
# 1565/1565 [==============================] - 291s 186ms/step - loss: 1.2598
# --- Generating with seed: " latter,
# their inmost heart, which would fain escape obedien"
# ------ temperature: 0.2
#  latter,
# their inmost heart, which would fain escape obedience as the spirit of the strength in the strength and conscience of the strength and strong and the stronger of the properly, the stronger of the standard in the strength and conscience of the sense of the sense of the suffering to the strength and the soul of the strength the fact of the strength and the soul of the stree of the sense of the same too conscience of the stree of the sense of the sou------ temperature: 0.5
# the same too conscience of the stree of the sense of the soul is not to learn to the spirit, in the presence of the truth of the sense that it is deathy with them constant it is the artistic of the more than the surelice of the soul would be all the consciences, the man who is one has with the seriotiwicatest conscience of the consciences of the constant of the fact that the sense of the most conclusions of the truth of the world of the masters of the orde------ temperature: 1.0
# lusions of the truth of the world of the masters of the order of
# the signoans, or sound taste with a peirges of something--later for nature would
# responsible here cultureem find distrust of schihess
# fail sedience thenve; and true domed (to means to
# say, and foundation, what not expres something themselves down them of caver's araiency thereby happy as inuthe first of the characthit on soul there may have for there
# instinct and greek and tasted, through the------ temperature: 1.2
# ay have for there
# instinct and greek and tasted, through the sme woulded outoraid, stoan, and plant, a great techary
# of the conmustion or as
# rediedly xur(more as -conk'stly". bulls.
# the tortorance. what termat, more
# old fad thyrious
# sounchamed, therefore, less cartely bro, meinatesiy the knyontless of the by intellect thinken
#
# un
# pences--that
# (evisuce, one of counssence subs.
# no meander hitalles the book of the most dourdedge, or tive genound perhaps be deepoch 39
#  288/1565 [====>.........................] - ETA: 3:32 - loss: 1.2239
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 1565/1565 [==============================] - 302s 193ms/step - loss: 1.2533
# --- Generating with seed: "test possibilities, and how often
# in the past the type man h"
# ------ temperature: 0.2
# test possibilities, and how often
# in the past the type man has always be all possibility of the contempt of the family and contempt of the sense of the subject of the superior of the fact of the sense of the subject of the contempt of the contention of the subjection of the subject of the superiority of the superior for the fact of the proper concern of man who has always also a superficial faith and for the subject of the sense of the most spirit is the s------ temperature: 0.5
# and for the subject of the sense of the most spirit is the sense of will in the possibility of the free spirit is a contemption of men in the great existence of the world and super that the soul has not been the
# historical soul was a soul is the regards to philosophy is the function is a sign as the general surpor of the scholary are this for the soul of the german degree of the functional of the instincts that it is the willing, and
# in the strength and pr------ temperature: 1.0
# instincts that it is the willing, and
# in the strength and privinges. there as the ideal. let the sugqueds acts of p, it is expedient far
# logical arguving withdest conscience, each morality that the aristoprs to the perspective, without--these noble clous spirit has gruys and hete
# so that the great peoples of man as his pupieoled close durgted can satisfint. the human philosopher alsw of sha-druped other recountless. but at least be all philosophen, thele a------ temperature: 1.2
#  other recountless. but at least be all philosophen, thele above him.
#
# 1194. that the stankor: laton wick ruine? so know what shate, ahe sees
# usled
# flecil to which no more is here, in ojutin about inject an existenced with luchery. a more thing of wird delights and resire,
# tnom occkin as
# his
# hape became condited but; in the uncestic
# their tile followingie or idints up: to say yet a manchers frayed, pleasure haugonity:, pospect.it
# see dword , wit: ty caatedepoch 43
#  853/1565 [===============>..............] - ETA: 2:55 - loss: 1.2385
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 1565/1565 [==============================] - 314s 200ms/step - loss: 1.2484
# --- Generating with seed: "dition. the individual is
# almost automatically bound to rule"
# ------ temperature: 0.2
# dition. the individual is
# almost automatically bound to rule the same of the same the same the same of the same of the sense of the most surplus of the most fact of the subject of the most surplus of the same and for the same really and the subject of the same of the present and the most successful to the problem of the same the same will to the same and the most gratitude and desire the personal consequently the same of the same will to the same will the ------ temperature: 0.5
# consequently the same of the same will to the same will the problem of the character in this devil of the spirit of the senses of consideration is the art of strain and true of the philosophers as a demands of morality in many one and the most something will understand them the for the consequences of the have a faculty of the same will to rest for the consequences of the belief of the truth of all the estimate of the intermination of the most surrest of t------ temperature: 1.0
# l the estimate of the intermination of the most surrest of the very high time
# originally attentally because something at last, which is who it is to conceally grataty, which in edubled of general time--cabist and flor of the value still at detarance of stree mastak. a emotion
# of enture--sociation of its believedly, as this, as he matter
# supers, however, thus have misundersy foreunder
# grows the newrush too innition of some stricging cluenessing of european ------ temperature: 1.2
# rush too innition of some stricging cluenessing of european frarb. almo: we element notively than seething dichoore rank on evernjy painted perhapsified, if the same causa, to them, as guiling that
# by the ulteman
# expstrruage okes of corse of simplifily, originalled could nature him, and they state, anothliness
# mixtrable is refearing natureness and harr, are for it; unhade the soul.
#
#
# 13

# %% [markdown]
# Note that by training a bigger model, longer, on more data, you can achieve gen-
# erated samples that look much more coherent and realistic than this one. But, of
# course, don’t expect to ever generate any meaningful text, other than by random
# chance: all you’re doing is sampling data from a statistical model of which characters
# come after which characters. Language is a communication channel, and there’s a
# distinction between what communications are about and the statistical structure of
# the messages in which communications are encoded.
